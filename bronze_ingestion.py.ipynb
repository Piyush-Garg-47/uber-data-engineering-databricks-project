# %% [markdown]
# # SPARK STREAMING

# %%
entities = ['customer' ,'drivers' , 'location', 'payment', 'trips', 'vehicles']

# %%
for entity in entities:
        df_batch = spark.read.format("csv")\
             .option("header", "true")\
             .option("inferSchema", "true")\
             .load(f"/Volumes/pysparkdbt/source/source_data/{entity}/")   
        schema_entity = df_batch.schema
        df = spark.readStream.format("csv")\
             .option("header", "true")\
             .schema(schema_entity)\
             .load(f"/Volumes/pysparkdbt/source/source_data/{entity}/")

        df.writeStream.format("delta")\
             .outputMode("append")\
             .option("checkpointLocation", f"/Volumes/pysparkdbt/bronze/checkpoint/{entity}")\
             .trigger(once=True)\
             .toTabletable(f"pysparkdbt.bronze.{entity}")
